# %% [markdown]
# # 🛒 E-Commerce Analytics ETL using FakeStore API
#
# This notebook builds an end-to-end ETL (Extract, Transform, Load) pipeline using the FakeStore API.
# The goal is to transform raw e-commerce API data into an analysis-ready dataset and derive key business metrics such as revenue and category performance.

# %%
import pandas as pd

# %% [markdown]
# ## 🔹 Extract
#
# In this step, we fetch raw data from the FakeStore API:
# - Product catalog data
# - Cart (transaction) data
#
# The API responses are returned in JSON format and contain nested structures that require transformation.

# %% [markdown]
# ### Fetching carts from FakeStoreAPI

# %%
import requests

url = "https://fakestoreapi.com/carts"
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
len(response.json())
# Out:
# 7

# %%
carts = response.json()
carts[0]
# Out:
# {'id': 1,
#  'userId': 1,
#  'date': '2020-03-02T00:00:00.000Z',
#  'products': [{'productId': 1, 'quantity': 4},
#   {'productId': 2, 'quantity': 1},
#   {'productId': 3, 'quantity': 6}],
#  '__v': 0}

# %% [markdown]
# ### Fetching Products

# %%
products = requests.get("https://fakestoreapi.com/products").json()

# %%
products[0]
# Out:
# {'id': 1,
#  'title': 'Fjallraven - Foldsack No. 1 Backpack, Fits 15 Laptops',
#  'price': 109.95,
#  'description': 'Your perfect pack for everyday use and walks in the forest. Stash your laptop (up to 15 inches) in the padded sleeve, your everyday',
#  'category': "men's clothing",
#  'image': 'https://fakestoreapi.com/img/81fPKd-2AYL._AC_SL1500_t.png',
#  'rating': {'rate': 3.9, 'count': 120}}

# %% [markdown]
# ## 🔹 Transform
#
# The transformation process includes:
# - Expanding each cart into multiple line items
# - Joining cart items with product data using product IDs
# - Calculating revenue at the product level
# - Ensuring consistent schema across all rows
#
# This step converts raw API responses into a clean, analysis-ready dataset.

# %% [markdown]
# ## 🔗 Joining Products with Carts
#
# To calculate revenue, cart data must be joined with product data.
#
# - Cart data provides **product ID and quantity**
# - Product data provides **price and category**
#
# A dictionary-based lookup is used to efficiently map:
#
# product_id → price, category

# %%
product_lookup={
    
    p['id']:{
        
        'category':p['category'],
        'price':p['price']
    }
    for p in products
}

# %%
product_lookup[3]["price"]
# Out:
# 55.99

# %%
rows=[]

for cart in carts:
    
    cart_id=cart['id']
    user_id=cart['userId']
    date=cart['date']
    
    for item in cart['products']:
        
        product_id=item['productId']
        quantity=item['quantity']
        
        price=product_lookup[product_id]['price']
        category=product_lookup[product_id]['category']
        
        revenue=price*quantity
        
        rows.append({
            "cart_id": cart_id,
            "user_id": user_id,
            "date": date,
            "product_id": product_id,
            "category": category,
            "price": price,
            "quantity": quantity,
            "revenue": revenue
        })

# %%
df=pd.DataFrame(rows)
df["date"] = pd.to_datetime(df["date"])
df = df.sort_values(["cart_id", "product_id"]).reset_index(drop=True)
df
# Out:
#     cart_id  user_id                      date  product_id          category  \
# 0         1        1 2020-03-02 00:00:00+00:00           1    men's clothing
# 1         1        1 2020-03-02 00:00:00+00:00           2    men's clothing
# 2         1        1 2020-03-02 00:00:00+00:00           3    men's clothing
# 3         2        1 2020-01-02 00:00:00+00:00           1    men's clothing
# 4         2        1 2020-01-02 00:00:00+00:00           2    men's clothing
# 5         2        1 2020-01-02 00:00:00+00:00           5          jewelery
# 6         3        2 2020-03-01 00:00:00+00:00           1    men's clothing
# 7         3        2 2020-03-01 00:00:00+00:00           9       electronics
# 8         4        3 2020-01-01 00:00:00+00:00           1    men's clothing
# 9         5        3 2020-03-01 00:00:00+00:00           7          jewelery
# 10        5        3 2020-03-01 00:00:00+00:00           8          jewelery
# 11        6        4 2020-03-01 00:00:00+00:00          10       electronics
# 12        6        4 2020-03-01 00:00:00+00:00          12       electronics
# 13        7        8 2020-03-01 00:00:00+00:00          18  women's clothing
#
#      price  quantity  revenue
# 0   109.95         4   439.80
# 1    22.30         1    22.30
# 2    55.99         6   335.94
# 3   109.95        10  1099.50
# 4    22.30         4    89.20
# 5   695.00         2  1390.00
# 6   109.95         2   219.90
# 7    64.00         1    64.00
# 8   109.95         4   439.80
# 9     9.99         1     9.99
# 10   10.99         1    10.99
# 11  109.00         2   218.00
# 12  114.00         3   342.00
# 13    9.85         1     9.85

# %% [markdown]
# ### Total Revenue by Categories

# %%
df.groupby("category")["revenue"].sum().sort_values(ascending=False)
# Out:
# category
# men's clothing      2646.44
# jewelery            1410.98
# electronics          624.00
# women's clothing       9.85
# Name: revenue, dtype: float64

# %% [markdown]
# ### High-performing products

# %%
df.groupby("product_id")["revenue"].sum().sort_values(ascending=False)
# Out:
# product_id
# 1     2199.00
# 5     1390.00
# 12     342.00
# 3      335.94
# 10     218.00
# 2      111.50
# 9       64.00
# 8       10.99
# 7        9.99
# 18       9.85
# Name: revenue, dtype: float64

# %% [markdown]
# ### Average Order Value (AOV)

# %%
order_revenue = df.groupby("cart_id")["revenue"].sum()
order_revenue.mean()
# Out:
# 670.1814285714285

# %% [markdown]
# ### Top customers

# %%
df.groupby("user_id")["revenue"].sum().sort_values(ascending=False)
# Out:
# user_id
# 1    3376.74
# 4     560.00
# 3     460.78
# 2     283.90
# 8       9.85
# Name: revenue, dtype: float64

# %% [markdown]
# ## Loading the Dataset

# %%
df.to_csv('Fake Store Dataset.csv', index=False)

print(f"Dataset saved succesfully!!")
# Out:
# Dataset saved succesfully!!
